# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('E:\Exercise Data.xlsx', header=1)

# %%
df
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
df.describe()
# Out:
#            Month  Contribution  Amount won by the bidder  \
# count  25.000000          25.0                 25.000000
# mean   13.000000        2000.0              43800.000000
# std     7.359801           0.0               2857.738033
# min     1.000000        2000.0              40000.000000
# 25%     7.000000        2000.0              42000.000000
# 50%    13.000000        2000.0              43000.000000
# 75%    19.000000        2000.0              45000.000000
# max    25.000000        2000.0              50000.000000
#
#        Chit fund organizer commission  Net amount recd by Bid winner  \
# count                            25.0                      25.000000
# mean                           2500.0                   41300.000000
# std                               0.0                    2857.738033
# min                            2500.0                   37500.000000
# 25%                            2500.0                   39500.000000
# ...

# %%
df.boxplot()

# %%
df['Amount returned to everyone in the group'].sum()
# Out:
# 6200

# %%
#creating a new column with summing

list=[]
col = df['Amount returned to everyone in the group']

sum = 0
list.append(0)
for num in col:
    sum += num
    list.append(sum)

# %%
list
# Out:
# [0,
#  400,
#  720,
#  920,
#  1000,
#  1400,
#  1720,
#  2000,
#  2240,
#  2640,
#  2960,
#  3160,
#  3240,
#  3640,
#  3960,
#  4240,
#  4520,
#  4880,
#  5200,
#  5400,
#  5600,
#  5840,
#  6000,
#  6120,
#  6200,
#  6200]

# %%
list1=list[:25]

# %%
list1
# Out:
# [0,
#  400,
#  720,
#  920,
#  1000,
#  1400,
#  1720,
#  2000,
#  2240,
#  2640,
#  2960,
#  3160,
#  3240,
#  3640,
#  3960,
#  4240,
#  4520,
#  4880,
#  5200,
#  5400,
#  5600,
#  5840,
#  6000,
#  6120,
#  6200]

# %%
df['Remaining amount returned to bid winner']=list1

# %%
df.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %%
df['Total amount returned to Bid Winner']=df['Net amount recd by Bid winner']+df['Remaining amount returned to bid winner']

# %%
df.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %%
df["Return % for each month's bid winner"]=(df['Total amount returned to Bid Winner']/50000)*100

# %%
df
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
sns.distplot(df["Total amount returned to Bid Winner"], kde=False,bins=10,color='b')

# %%
df[["Total amount returned to Bid Winner","Return % for each month's bid winner"]]
# Out:
#     Total amount returned to Bid Winner  Return % for each month's bid winner
# 0                                 37500                                 75.00
# 1                                 39900                                 79.80
# 2                                 43220                                 86.44
# 3                                 46420                                 92.84
# 4                                 38500                                 77.00
# 5                                 40900                                 81.80
# 6                                 42220                                 84.44
# 7                                 43500                                 87.00
# 8                                 39740                                 79.48
# 9                                 42140                                 84.28
# 10                                45460                                 90.92
# ...

# %%
# Percentage returns for each months bid winner
df["Return % for each month's bid winner"]
# Out:
# 0      75.00
# 1      79.80
# 2      86.44
# 3      92.84
# 4      77.00
# 5      81.80
# 6      84.44
# 7      87.00
# 8      79.48
# 9      84.28
# 10     90.92
# 11     97.32
# 12     81.48
# 13     86.28
# 14     88.92
# 15     89.48
# 16     86.04
# 17     88.76
# 18     95.40
# 19     95.80
# 20     94.20
# 21     98.68
# 22    101.00
# 23    103.24
# 24    107.40
# Name: Return % for each month's bid winner, dtype: float64

# %% [markdown]
# # Task Given :
# ## • What is the Annualized Return of the person who bids in the last month ?
# ### 25 months- invetsed 2000per/month = 50,000 -
# ### Returns= 53700rs -i.e 107.40%

# %% [markdown]
# ## • What is the Annualized Return of the person who bids in the first month ?
# ### 25 months- invetsed 2000per/month = 50,000 -
# ### Returns= 37500rs - i.e 75.00%

# %% [markdown]
# ## • Write an R/Python script which calculates the annualized return of chit fund participant ?- Show the Return % for each month's bid winner.¶
# ## Month - , -Total amount returned to Bid Winner each month - , - Return % for each month's bid winner
# ### 0 - 37500rs - 75.00%
# ### 1 - 39900rs - 79.80%
# ### 2 - 43220rs - 86.44%
# ### 3 - 46420rs - 92.84%
# ### 4 - 38500rs - 77.00%
# ### 5 - 40900rs - 81.80%
# ### 6 - 42220rs - 84.44%
# ### 7 - 43500rs - 87.00%
# ### 8 - 39740rs - 79.48%
# ### 9 - 42140rs - 84.28%
# ### 10 - 45460rs - 90.92%
# ### 11 - 48660rs - 97.32%
# ### 12 - 40740rs - 81.48%
# ### 13 - 43140rs - 86.28%
# ### 14 - 44460rs - 88.92%
# ### 15 - 44740rs - 89.48%
# ### 16 - 43020rs - 86.04%
# ### 17 - 44380rs - 88.76%
# ### 18 - 47700rs - 95.40%
# ### 19 - 47900rs - 95.80%
# ### 20 - 47100rs - 94.20%
# ### 21 - 49340rs - 98.68%
# ### 22 - 50500rs - 101.00%
# ### 23 - 51620rs - 103.24%
# ### 24 - 53700rs - 107.40%
# #### index in python starts from Zero i.e 24slno is 25th month
